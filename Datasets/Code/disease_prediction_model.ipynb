# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ## EDA

# %%
# import the dataset
dataset_df = pd.read_csv('dataset (1).csv')

# %%
dataset_df.head()
# Out:
#   Disease           Symptom_0           Symptom_1                Symptom_2  \
# 0    AIDS      muscle_wasting   patches_in_throat               high_fever
# 1    AIDS   patches_in_throat          high_fever   extra_marital_contacts
# 2    AIDS      muscle_wasting          high_fever   extra_marital_contacts
# 3    AIDS      muscle_wasting   patches_in_throat   extra_marital_contacts
# 4    AIDS      muscle_wasting   patches_in_throat               high_fever
#
#                  Symptom_3 Symptom_4 Symptom_5 Symptom_6 Symptom_7 Symptom_8  \
# 0   extra_marital_contacts       NaN       NaN       NaN       NaN       NaN
# 1                      NaN       NaN       NaN       NaN       NaN       NaN
# 2                      NaN       NaN       NaN       NaN       NaN       NaN
# 3                      NaN       NaN       NaN       NaN       NaN       NaN
# 4                      NaN       NaN       NaN       NaN       NaN       NaN
#
#   Symptom_9 Symptom_10 Symptom_11 Symptom_12 Symptom_13 Symptom_14 Symptom_15  \
# 0       NaN        NaN        NaN        NaN        NaN        NaN        NaN
# 1       NaN        NaN        NaN        NaN        NaN        NaN        NaN
# 2       NaN        NaN        NaN        NaN        NaN        NaN        NaN
# 3       NaN        NaN        NaN        NaN        NaN        NaN        NaN
# 4       NaN        NaN        NaN        NaN        NaN        NaN        NaN
#
#   Symptom_16
# 0        NaN
# 1        NaN
# 2        NaN
# 3        NaN
# 4        NaN

# %% [markdown]
# There are 4930 patients

# %%
dataset_df.shape
# Out:
# (313, 18)

# %%
dataset_df = dataset_df.apply(lambda col: col.str.strip())

# %%
test = pd.get_dummies(dataset_df.filter(regex='Symptom'), prefix='', prefix_sep='')

# %%
test.head()
# Out:
#    acidity  back_pain  bladder_discomfort  breathlessness  \
# 0    False      False               False           False
# 1    False      False               False           False
# 2    False      False               False           False
# 3    False      False               False           False
# 4    False      False               False           False
#
#    burning_micturition  chest_pain  chills  constipation  continuous_sneezing  \
# 0                False       False   False         False                False
# 1                False       False   False         False                False
# 2                False       False   False         False                False
# 3                False       False   False         False                False
# 4                False       False   False         False                False
#
#    cough  ...  congestion  phlegm  red_spots_over_body  blood_in_sputum  \
# 0  False  ...       False   False                False            False
# 1  False  ...       False   False                False            False
# 2  False  ...       False   False                False            False
# 3  False  ...       False   False                False            False
# 4  False  ...       False   False                False            False
#
#    chest_pain  loss_of_smell  blood_in_sputum  loss_of_smell  muscle_pain  \
# 0       False          False            False          False        False
# 1       False          False            False          False        False
# 2       False          False            False          False        False
# 3       False          False            False          False        False
# 4       False          False            False          False        False
#
#    muscle_pain
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#
# [5 rows x 404 columns]

# %%
test = test.groupby(test.columns, axis=1).agg(np.max)
# Out:
# C:\Users\agarw\AppData\Local\Temp\ipykernel_12032\3730348491.py:1: FutureWarning: DataFrame.groupby with axis=1 is deprecated. Do `frame.T.groupby(...)` without axis instead.
#   test = test.groupby(test.columns, axis=1).agg(np.max)
# C:\Users\agarw\AppData\Local\Temp\ipykernel_12032\3730348491.py:1: FutureWarning: The provided callable <function max at 0x000001F5D6367740> is currently using DataFrameGroupBy.max. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "max" instead.
#   test = test.groupby(test.columns, axis=1).agg(np.max)

# %%
clean_df = pd.merge(test,dataset_df['Disease'], left_index=True, right_index=True)

# %%
clean_df
# Out:
#      abdominal_pain  abnormal_menstruation  acidity  acute_liver_failure  \
# 0             False                  False    False                False
# 1             False                  False    False                False
# 2             False                  False    False                False
# 3             False                  False    False                False
# 4             False                  False    False                False
# ..              ...                    ...      ...                  ...
# 308           False                  False    False                False
# 309           False                  False    False                False
# 310           False                  False    False                False
# 311           False                  False    False                False
# 312           False                  False    False                False
#
#      altered_sensorium  anxiety  back_pain  belly_pain  blackheads  \
# 0                False    False      False       False       False
# 1                False    False      False       False       False
# 2                False    False      False       False       False
# 3                False    False      False       False       False
# 4                False    False      False       False       False
# ..                 ...      ...        ...         ...         ...
# 308              False    False      False       False       False
# 309              False    False      False       False       False
# 310              False    False      False       False       False
# 311              False    False      False       False       False
# 312              False    False      False       False       False
#
#      bladder_discomfort  ...  watering_from_eyes  weakness_in_limbs  \
# 0                 False  ...               False              False
# 1                 False  ...               False              False
# 2                 False  ...               False              False
# 3                 False  ...               False              False
# 4                 False  ...               False              False
# ..                  ...  ...                 ...                ...
# 308               False  ...               False              False
# 309               False  ...               False              False
# 310               False  ...               False              False
# 311               False  ...               False              False
# 312               False  ...               False              False
#
#      weakness_of_one_body_side  weight_gain  weight_loss  yellow_crust_ooze  \
# 0                        False        False        False              False
# 1                        False        False        False              False
# 2                        False        False        False              False
# 3                        False        False        False              False
# 4                        False        False        False              False
# ..                         ...          ...          ...                ...
# 308                      False        False        False              False
# 309                      False        False        False              False
# 310                      False        False        False              False
# 311                      False        False        False              False
# 312                      False        False        False              False
#
#      yellow_urine  yellowing_of_eyes  yellowish_skin         Disease
# 0           False              False           False            AIDS
# 1           False              False           False            AIDS
# 2           False              False           False            AIDS
# 3           False              False           False            AIDS
# 4           False              False           False            AIDS
# ..            ...                ...             ...             ...
# 308         False              False           False  Varicose veins
# 309         False              False           False  Varicose veins
# 310         False              False           False  Varicose veins
# 311         False              False           False  Varicose veins
# 312         False              False           False  Varicose veins
#
# [313 rows x 134 columns]

# %%
clean_df.columns.get_loc('acidity')
# Out:
# 2

# %%
test = np.zeros((1,132))

# %%
test[0,12]
# Out:
# 0.0

# %% [markdown]
# Machine learning model: XGBoost random forest classifier

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score
from sklearn.ensemble import GradientBoostingClassifier
from sklearn import preprocessing

# %%
X_data = clean_df.iloc[:,:-1]
y_data = clean_df.iloc[:,-1]

# Convert y to categorical values
y_data = y_data.astype('category')

# %%
X_data.shape
# Out:
# (313, 133)

# %%
y_data.shape
# Out:
# (313,)

# %%
le = preprocessing.LabelEncoder()
le.fit(y_data)
# Out:
# LabelEncoder()

# %%
y_data.cat.categories
# Out:
# Index(['AIDS', 'Acne', 'Alcoholic hepatitis', 'Allergy', 'Arthritis',
#        'Bronchial Asthma', 'Cervical spondylosis', 'Chicken pox',
#        'Chronic cholestasis', 'Common Cold', 'Covid', 'Dengue', 'Diabetes',
#        'Dimorphic hemorrhoids(piles)', 'Drug Reaction', 'Fungal infection',
#        'GERD', 'Gastroenteritis', 'Heart attack', 'Hepatitis A', 'Hepatitis B',
#        'Hepatitis C', 'Hepatitis D', 'Hepatitis E', 'Hypertension',
#        'Hyperthyroidism', 'Hypoglycemia', 'Hypothyroidism', 'Impetigo',
#        'Jaundice', 'Malaria', 'Migraine', 'Osteoarthritis',
#        'Paralysis (brain hemorrhage)', 'Paroxysmal Positional Vertigo',
#        'Peptic ulcer disease', 'Pneumonia', 'Psoriasis', 'Tuberculosis',
#        'Typhoid', 'Urinary tract infection', 'Varicose veins'],
#       dtype='object')

# %%
X_train, X_test, y_train, y_test = train_test_split(X_data, y_data, test_size=0.2)

# %%
X_train.shape
# Out:
# (250, 133)

# %%
X_test.shape
# Out:
# (63, 133)

# %%
# Convert labels to numbers
y_train = le.transform(y_train)
y_test = le.transform(y_test)

# %%
import xgboost as xgb

# Init classifier
model = xgb.XGBClassifier()

# Fit
model.fit(X_train, y_train)

# Predict
preds = model.predict(X_test)

# %%
le.inverse_transform(model.predict(X_test.iloc[1,:].to_numpy().reshape(1,-1)))
# Out:
# array(['Common Cold'], dtype=object)

# %%
y_data.cat.categories[1]
# Out:
# 'Acne'

# %%
model.predict(X_test.iloc[2,:].to_numpy().reshape(1,-1))
# Out:
# array([10], dtype=int64)

# %%
model.predict_proba(X_test.iloc[2,:].to_numpy().reshape(1,-1))[0,15]
# Out:
# 0.0006906497

# %%
accuracy_score(y_test, preds)
# Out:
# 0.873015873015873

# %%
y_test
# Out:
# array([ 1,  9, 10, 23, 23, 36, 37, 38, 21,  8,  2,  6, 25, 24, 20, 27, 28,
#        14, 22, 19, 27,  7, 38, 23, 29, 35,  2, 22, 31,  8, 35,  4, 30, 40,
#        39, 38, 29, 35, 26, 25, 27, 16, 36, 41, 12,  6,  3, 26, 11, 41,  0,
#        37, 36, 31,  0, 10, 18, 36, 31, 24,  5, 14,  7])

# %%
print(classification_report(y_test, preds))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.67      1.00      0.80         2
#            1       1.00      1.00      1.00         1
#            2       1.00      1.00      1.00         2
#            3       1.00      1.00      1.00         1
#            4       0.50      1.00      0.67         1
#            5       1.00      1.00      1.00         1
#            6       1.00      0.50      0.67         2
#            7       1.00      1.00      1.00         2
#            8       0.67      1.00      0.80         2
#            9       1.00      1.00      1.00         1
#           10       1.00      1.00      1.00         2
#           11       1.00      1.00      1.00         1
#           12       1.00      1.00      1.00         1
#           13       0.00      0.00      0.00         0
#           14       1.00      0.50      0.67         2
#           15       0.00      0.00      0.00         0
#           16       1.00      1.00      1.00         1
#           18       0.00      0.00      0.00         1
#           19       1.00      1.00      1.00         1
#           20       1.00      1.00      1.00         1
#           21       1.00      1.00      1.00         1
#           22       1.00      0.50      0.67         2
#           23       1.00      1.00      1.00         3
#           24       0.50      1.00      0.67         2
#           25       1.00      1.00      1.00         2
#           26       1.00      1.00      1.00         2
#           27       1.00      1.00      1.00         3
#           28       0.00      0.00      0.00         1
#           29       1.00      1.00      1.00         2
#           30       1.00      1.00      1.00         1
#           31       1.00      0.67      0.80         3
#           32       0.00      0.00      0.00         0
#           35       1.00      1.00      1.00         3
#           36       1.00      1.00      1.00         4
#           37       1.00      0.50      0.67         2
#           38       1.00      1.00      1.00         3
#           39       1.00      1.00      1.00         1
#           40       0.00      0.00      0.00         1
#           41       1.00      1.00      1.00         2
#
#     accuracy                           0.87        63
#    macro avg       0.80      0.79      0.78        63
# weighted avg       0.91      0.87      0.87        63
# C:\Users\agarw\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\metrics\_classification.py:1471: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\agarw\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\metrics\_classification.py:1471: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\agarw\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\metrics\_classification.py:1471: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\agarw\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\metrics\_classification.py:1471: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\agarw\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\metrics\_classification.py:1471: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\agarw\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\metrics\_classification.py:1471: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
y_train.cat.categories
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[32], line 1
# ----> 1 y_train.cat.categories
#
# AttributeError: 'numpy.ndarray' object has no attribute 'cat'

# %%
y_train.cat.categories.

# %%
y_train.cat.categories.to_list()

# %%
# import the dataset
desc_df = pd.read_csv('../data/symptom_Description.csv')

# %%
desc_df[desc_df['Disease'] == 'Malaria']['Description'].values[0]

# %%
prec_df = pd.read_csv('../data/symptom_precaution.csv')

# %%
prec_df[prec_df['Disease'] == 'Malaria'].filter(regex='Precaution').values.tolist()[0]

# %%
pd.read_csv('../data/clean_dataset.tsv', sep='\t')
